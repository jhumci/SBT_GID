# %% [markdown]
# <table style="width: 100%">
#     <tr style="background: #ffffff">
#         <td style="padding-top:25px;width: 180px"><img src="https://mci.edu/templates/mci/images/logo.svg" alt="Logo"></td>
#         <td style="width: 100%">
#             <div style="text-align:right; width: 100%; text-align:right"><font style="font-size:38px"><b>Grundlagen Programmierung</b></font></div>
#             <div style="padding-top:0px; width: 100%; text-align:right"><font size="4"><b>WS 2022</b></font></div>
#         </td>
#     </tr>
# </table>
#
# ---
#
# # Structured Query Language
#
# SQL ist die wichtigste Sprache zur Auswertung und Manipulation von relational strukturierten Daten. Überlicher Weise wird diese Sprache genutzt, um direkt mit einer Datenbank zu kommunizieren.
#
# Dieses Jupyter-Notebook enthält stattdessen eine Tabelle (im DataFrame ```performance_data```), die wird im Folgenden wie eine SQL-Datenbank über SQL-Befehle auswerten.
#
# ## Vorbereitung des Notebooks
#
# Hier nichts verändern. Zunächst werden einige Befehle ausgeführt, im die nötigen Python-Pakte zu installieren.
#
# ✍️ **Aufgabe**
#
# Führen Sie die folgende Zelle aus.

# %%
# Installiert Paket, damit man SQL-Befehle auf Dataframes anwenden kann
# !pip install pandasql

# Lädt Paket, damit man Dataframes (Tabellen in Python) anwenden kann
import pandas as pd
# Lädt Paket, damit man SQL-Befehle auf Dataframes anwenden kann
import pandasql as ps

import numpy as np
# Out:
# Requirement already satisfied: pandasql in c:\users\jlhuber\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: sqlalchemy in c:\users\jlhuber\anaconda3\lib\site-packages (from pandasql) (1.4.7)
# Requirement already satisfied: pandas in c:\users\jlhuber\anaconda3\lib\site-packages (from pandasql) (1.2.4)
# Requirement already satisfied: numpy in c:\users\jlhuber\anaconda3\lib\site-packages (from pandasql) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jlhuber\anaconda3\lib\site-packages (from pandas->pandasql) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jlhuber\anaconda3\lib\site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\jlhuber\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jlhuber\anaconda3\lib\site-packages (from sqlalchemy->pandasql) (1.0.0)

# %% [markdown]
# ## Datenbeschreibung
#
# ✍️ Laden Sie zunächst die CSV-Datei `Staedtischer_Baumkataster.csv` aus Sakai hier hier hoch.
#
# Dazu müssen Sie auf der liken Seite zurnächst auf das Ordner-Symbol und dann auf den Upload-Pfeil klicken und die Datei auswählen.
# Neben den bekannten Daten wird dem Datensatz noch eine Spalte mit (fiktiven) Baumhöhen hinzugefügt.
#
# ![image.png](data:image/png;base64,...)
#
# In der Vergangenheit (2022) kam es hier zu Problemen beim Firefox Browser. Wenn Probleme beim Upload auftreten, testen Sie einen anderen Webbrowser.
#
# Im nächsten Schritt werden die Daten von Python aus der CSV-Datei in einen DataFrame geladen. Dies ist ein spezieller Datentyp für Tabellen.
#
# Zudem wird eine zufällig Baumhöhe simuliert, die nicht in den ursprünglichen Daten enthalten ist.

# %%
# Lade die Daten in einen pandas Dataframe namens "performance_data"
performance_data = pd.read_csv("Staedtischer_Baumkataster.csv", delimiter = ";")

performance_data["X"] = performance_data["X"].str.replace(",",".").astype("float")
performance_data["Y"] = performance_data["Y"].str.replace(",",".").astype("float")
performance_data["Lon"] = performance_data["Lon"].str.replace(",",".").astype("float")
performance_data["Lat"] = performance_data["Lat"].str.replace(",",".").astype("float")

# Setting a random seed, so everyone has the same data
np.random.seed(10)

# Random hight, no real data
performance_data["Height_m"] = np.random.randint(2,20, size=len(performance_data))

# Zeige performance_data an
performance_data
# Out:
#        OBJECTID                      Anlage Baumnummer  \
# 0             1  Kaiser-Franz-Joseph-Straße         17
# 1             2  Kaiser-Franz-Joseph-Straße         18
# 2             3  Kaiser-Franz-Joseph-Straße         19
# 3             4  Kaiser-Franz-Joseph-Straße         23
# 4             5  Kaiser-Franz-Joseph-Straße         26
# ...         ...                         ...        ...
# 13412     13413             Friedhof Mühlau         76
# 13413     13414        Haller Straße - West        128
# 13414     13415   Hans-Flöckinger-Promenade        117
# 13415     13416   Hans-Flöckinger-Promenade        178
# 13416     13417                      Wilten        149
#
#                         Gattung_Dt                         Gattung_Lat  \
# 0                      Winterlinde                       Tilia cordata
# 1                      Winterlinde                       Tilia cordata
# 2                      Winterlinde                       Tilia cordata
# 3                      Winterlinde                       Tilia cordata
# 4                      Winterlinde                       Tilia cordata
# ...                            ...                                 ...
# 13412                        Föhre                    Pinus sylvestris
# 13413                  Hopfenbuche                 Ostrya carpinifolia
# 13414  Japanische Nelken - Kirsche  Prunus serrulata 'Pink Perfektion'
# 13415                  Zierkirsche       Prunus subhirtella 'Accolade'
# 13416                    Sandbirke                      Betula pendula
#
#       Pflanzdatum           X            Y        Lon        Lat  Height_m
# 0             NaN  81264.6040  238116.5790  11.407063  47.276884        11
# 1             NaN  81257.6270  238109.1460  11.406970  47.276818         6
# 2             NaN  81251.1200  238102.3230  11.406882  47.276757        17
# 3             NaN  81223.8600  238073.6500  11.406517  47.276503         2
# 4             NaN  81203.5300  238052.2200  11.406244  47.276313        19
# ...           ...         ...          ...        ...        ...       ...
# 13412         NaN  81875.3952  238982.9465  11.415293  47.284599        13
# 13413  19.11.2020  83057.0921  237967.1521  11.430722  47.275316        13
# 13414  25.11.2020  78932.1855  235878.7458  11.375848  47.257042         3
# 13415  26.11.2020  78667.3363  235545.6759  11.372291  47.254079        16
# 13416         NaN  79720.2336  236123.0044  11.386301  47.259144         8
#
# [13417 rows x 11 columns]

# %% [markdown]
# ## SQL-Befehle
#
# Die `ps.sqldf()` Funktion erlaubt es SQL-Befehle statt auf Datenbank auf pandas Dataframes auszuführen. Wir setzen das ein, um uns die Einrichtung einer echten Datenbank für diese Übung zu sparten. Der Funktion wird der eigentliche SQL-Befehl als Sting übergeben:
#
# ```"SELECT * FROM performance_data"```
#
# SELECT und FROM sind Schlüsselwörter der SQL-Sprache und werden deswegen großgeschrieben. ```performance_data``` ist der Name der Tabelle/Relation von der wir abfragen wollen. das ```*``` ist eine sogenannte Wildcard und bedeuted, dass wir alle Attribute der Tabelle ausgeben wollen:
#
# Um den SQL-Befehl in Python zu nutzen, müssen wir ihn nun in die `ps.sqldf()` Funktion verpacken:
#
# ```ps.sqldf("""SELECT * FROM performance_data""") # Gibt die gesamte Tabelle performance_data aus```
#
# Wir setzen dreifache Anführungszeichen um den SQL-Befehl, da wir somit auch einfache Anführungszeichen im SQL-Befehl selbst nutzen können, ohne dass Python den String beim zweiten Auftreten eines Anführungszeichens für beendet hält.
#
# [Hier](https://www.dataquest.io/blog/sql-basics/) findet sich eine ausführliche Erklärung dieser und weiterer SQL-Befehle.

# %%
ps.sqldf("SELECT * FROM performance_data") # Gibt die gesamte Tabelle performance_data aus
# Out:
#        OBJECTID                      Anlage Baumnummer  \
# 0             1  Kaiser-Franz-Joseph-Straße         17
# 1             2  Kaiser-Franz-Joseph-Straße         18
# 2             3  Kaiser-Franz-Joseph-Straße         19
# 3             4  Kaiser-Franz-Joseph-Straße         23
# 4             5  Kaiser-Franz-Joseph-Straße         26
# ...         ...                         ...        ...
# 13412     13413             Friedhof Mühlau         76
# 13413     13414        Haller Straße - West        128
# 13414     13415   Hans-Flöckinger-Promenade        117
# 13415     13416   Hans-Flöckinger-Promenade        178
# 13416     13417                      Wilten        149
#
#                         Gattung_Dt                         Gattung_Lat  \
# 0                      Winterlinde                       Tilia cordata
# 1                      Winterlinde                       Tilia cordata
# 2                      Winterlinde                       Tilia cordata
# 3                      Winterlinde                       Tilia cordata
# 4                      Winterlinde                       Tilia cordata
# ...                            ...                                 ...
# 13412                        Föhre                    Pinus sylvestris
# 13413                  Hopfenbuche                 Ostrya carpinifolia
# 13414  Japanische Nelken - Kirsche  Prunus serrulata 'Pink Perfektion'
# 13415                  Zierkirsche       Prunus subhirtella 'Accolade'
# 13416                    Sandbirke                      Betula pendula
#
#       Pflanzdatum           X            Y        Lon        Lat  Height_m
# 0            None  81264.6040  238116.5790  11.407063  47.276884        11
# 1            None  81257.6270  238109.1460  11.406970  47.276818         6
# 2            None  81251.1200  238102.3230  11.406882  47.276757        17
# 3            None  81223.8600  238073.6500  11.406517  47.276503         2
# 4            None  81203.5300  238052.2200  11.406244  47.276313        19
# ...           ...         ...          ...        ...        ...       ...
# 13412        None  81875.3952  238982.9465  11.415293  47.284599        13
# 13413  19.11.2020  83057.0921  237967.1521  11.430722  47.275316        13
# 13414  25.11.2020  78932.1855  235878.7458  11.375848  47.257042         3
# 13415  26.11.2020  78667.3363  235545.6759  11.372291  47.254079        16
# 13416        None  79720.2336  236123.0044  11.386301  47.259144         8
#
# [13417 rows x 11 columns]

# %% [markdown]
# ## Projektion
#
# Durch eine Projektion werden einzelne Attribute aus einer Tabelle abgefragt. Hierzu werden die Attribute hinter der SELECT genannt und mit einen Komma voneinander abgetrennt.
#
# ```ps.sqldf("SELECT Anlage FROM performance_data") # Gibt Anlage aus```
#
#
# ```ps.sqldf("SELECT Anlage, Baumnummer FROM performance_data") # Gibt Anlage und Baumnummer aus```

# %%
# Beispiel
ps.sqldf("SELECT Anlage FROM performance_data") # Gibt sex aus
# Out:
#                            Anlage
# 0      Kaiser-Franz-Joseph-Straße
# 1      Kaiser-Franz-Joseph-Straße
# 2      Kaiser-Franz-Joseph-Straße
# 3      Kaiser-Franz-Joseph-Straße
# 4      Kaiser-Franz-Joseph-Straße
# ...                           ...
# 13412             Friedhof Mühlau
# 13413        Haller Straße - West
# 13414   Hans-Flöckinger-Promenade
# 13415   Hans-Flöckinger-Promenade
# 13416                      Wilten
#
# [13417 rows x 1 columns]

# %%
# Beispiel
ps.sqldf("SELECT Anlage, Baumnummer  FROM performance_data") # Gibt gender und age aus
# Out:
#                            Anlage Baumnummer
# 0      Kaiser-Franz-Joseph-Straße         17
# 1      Kaiser-Franz-Joseph-Straße         18
# 2      Kaiser-Franz-Joseph-Straße         19
# 3      Kaiser-Franz-Joseph-Straße         23
# 4      Kaiser-Franz-Joseph-Straße         26
# ...                           ...        ...
# 13412             Friedhof Mühlau         76
# 13413        Haller Straße - West        128
# 13414   Hans-Flöckinger-Promenade        117
# 13415   Hans-Flöckinger-Promenade        178
# 13416                      Wilten        149
#
# [13417 rows x 2 columns]

# %% [markdown]
# ## Selektion
#
# Auswahl einer Untermenge aller Tupel einer Tabelle.
# Die Selektion wird durch zusätzliche Schlüsselwörter hinter der Auswahl der Tabelle (FROM performance_data) angefügt.
#
# Beispielsweise lässt sich die Ausgabe auf fünf Einträge begrenzen:
#
# ```ps.sqldf("SELECT Anlage, Baumnummer FROM performance_data LIMIT 5")```

# %%
# Beispiel
ps.sqldf("SELECT Anlage, Baumnummer FROM performance_data LIMIT 5") # Gibt die ersten  Einträge aus
# Out:
#                        Anlage Baumnummer
# 0  Kaiser-Franz-Joseph-Straße         17
# 1  Kaiser-Franz-Joseph-Straße         18
# 2  Kaiser-Franz-Joseph-Straße         19
# 3  Kaiser-Franz-Joseph-Straße         23
# 4  Kaiser-Franz-Joseph-Straße         26

# %% [markdown]
# ## Besprechung der Aufgaben
#
# - Sind Sie mit ein Aufgaben bis hierhin fertig geworden und haben Sie keine Fragen, so legen Sie die grüne Karte nach oben
# - Sind Sie mit den Aufgaben fertig, aber hätten gerne, dass die Lösungen nocheinmal gemeinsam besprochen werden, legen Sie die gelbe Karte nach oben
#
# ![](https://www.lokalinfo.ch/fileadmin/news_import/image003_03.jpg)

# %% [markdown]
# ### Filtern
#
# - Eine besondere Art von Selektion ist das Filtern
# - Beim Filtern wird das Schlüsselwort ```WHERE``` genutzt. Darauf folgt eine logische Abfrage z.B. bezüglich des Attributs ```Anlage``` ob dieses der `"	Kaiser-Franz-Joseph-Straße"` entspricht.
#
# ```ps.sqldf("""SELECT Anlage, Baumnummer, Gattung_Dt FROM performance_data WHERE Anlage="Kaiser-Franz-Joseph-Straße" """)```
#
# *Vorsicht:* der SQL-Befehl enthält " um den String zu kennzeichnen. Damit Python diesen nicht mit dem Anfang und Ende der SQL-Abfrage verwechselt, wird diese jetzt mit """ (drei ") gekennzeichnet *

# %%
# Beispiel
ps.sqldf("""SELECT Anlage, Baumnummer, Gattung_Dt FROM performance_data WHERE Anlage="Kaiser-Franz-Joseph-Straße" """)
# Out:
#                         Anlage Baumnummer   Gattung_Dt
# 0   Kaiser-Franz-Joseph-Straße         17  Winterlinde
# 1   Kaiser-Franz-Joseph-Straße         18  Winterlinde
# 2   Kaiser-Franz-Joseph-Straße         19  Winterlinde
# 3   Kaiser-Franz-Joseph-Straße         23  Winterlinde
# 4   Kaiser-Franz-Joseph-Straße         26  Winterlinde
# 5   Kaiser-Franz-Joseph-Straße         27  Winterlinde
# 6   Kaiser-Franz-Joseph-Straße         28  Winterlinde
# 7   Kaiser-Franz-Joseph-Straße         29  Winterlinde
# 8   Kaiser-Franz-Joseph-Straße         30  Winterlinde
# 9   Kaiser-Franz-Joseph-Straße         31  Winterlinde
# 10  Kaiser-Franz-Joseph-Straße         32  Winterlinde
# 11  Kaiser-Franz-Joseph-Straße          1  Winterlinde
# 12  Kaiser-Franz-Joseph-Straße          2  Winterlinde
# 13  Kaiser-Franz-Joseph-Straße          4  Winterlinde
# 14  Kaiser-Franz-Joseph-Straße          5  Winterlinde
# 15  Kaiser-Franz-Joseph-Straße          8  Winterlinde
# 16  Kaiser-Franz-Joseph-Straße          9  Winterlinde
# 17  Kaiser-Franz-Joseph-Straße         10  Winterlinde
# 18  Kaiser-Franz-Joseph-Straße         11  Winterlinde
# 19  Kaiser-Franz-Joseph-Straße         12  Winterlinde
# 20  Kaiser-Franz-Joseph-Straße         13  Winterlinde
# 21  Kaiser-Franz-Joseph-Straße         14  Winterlinde
# 22  Kaiser-Franz-Joseph-Straße          6  Winterlinde
# 23  Kaiser-Franz-Joseph-Straße         20  Winterlinde
# 24  Kaiser-Franz-Joseph-Straße          7   Stadtlinde
# 25  Kaiser-Franz-Joseph-Straße         16  Winterlinde
# 26  Kaiser-Franz-Joseph-Straße          3  Winterlinde
# 27  Kaiser-Franz-Joseph-Straße         15  Winterlinde
# 28  Kaiser-Franz-Joseph-Straße         25   Stadtlinde
# 29  Kaiser-Franz-Joseph-Straße         22  Winterlinde
# 30  Kaiser-Franz-Joseph-Straße         24  Winterlinde
# 31  Kaiser-Franz-Joseph-Straße         21  Winterlinde

# %% [markdown]
# Filter-Operationen können auch vergleichend sein (größer, kleiner, etc.) und können mit logischen Operatoren verknüpft werden z.B. mit `AND` um nur Einträge zu finden, bei denen zwei Bedingungen zutreffen:

# %%
# Beispiel
ps.sqldf("""SELECT * FROM performance_data WHERE Lat<	47.27688375 AND  Lon>11.4068823""")
# Out:
#       OBJECTID                                             Anlage Baumnummer  \
# 0            2                         Kaiser-Franz-Joseph-Straße         18
# 1            3                         Kaiser-Franz-Joseph-Straße         19
# 2           17                                     Kapuzinergasse          5
# 3           18                                     Kapuzinergasse          8
# 4           19                                     Kapuzinergasse         10
# ...        ...                                                ...        ...
# 6035     13403  Grüngürtel Reichenau West - Spiel- und Sportan...         69
# 6036     13404  Grüngürtel Reichenau West - Spiel- und Sportan...         70
# 6037     13405  Grüngürtel Reichenau West - Spiel- und Sportan...         71
# 6038     13406  Grüngürtel Reichenau West - Spiel- und Sportan...         72
# 6039     13414                               Haller Straße - West        128
#
#            Gattung_Dt                           Gattung_Lat Pflanzdatum  \
# 0         Winterlinde                         Tilia cordata        None
# 1         Winterlinde                         Tilia cordata        None
# 2         Roßkastanie                Aesculus hippocastanum        None
# 3         Winterlinde                         Tilia cordata        None
# 4         Winterlinde                         Tilia cordata        None
# ...               ...                                   ...         ...
# 6035           Ginkgo                         Ginkgo biloba  26.11.2020
# 6036  Säulenamberbaum  Liquidambar styraciflua 'Fastigiata'  26.11.2020
# 6037       Tulpenbaum               Liriodendron tulipifera  26.11.2020
# 6038      Winterlinde                         Tilia cordata  26.11.2020
# 6039      Hopfenbuche                   Ostrya carpinifolia  19.11.2020
#
#                X            Y        Lon        Lat
# 0     81257.6270  238109.1460  11.406970  47.276818
# 1     81251.1200  238102.3230  11.406882  47.276757
# 2     81292.5500  237539.7700  11.407328  47.271693
# 3     81333.8010  237561.4920  11.407877  47.271883
# 4     81346.7740  237569.6300  11.408050  47.271955
# ...          ...          ...        ...        ...
# 6035  82221.1901  237754.5043  11.419637  47.273509
# 6036  82227.1965  237771.3789  11.419720  47.273660
# 6037  82213.3743  237750.6546  11.419533  47.273475
# 6038  82208.0073  237758.5301  11.419464  47.273547
# 6039  83057.0921  237967.1521  11.430722  47.275316
#
# [6040 rows x 10 columns]

# %% [markdown]
# ## Ausgaben verarbeiten
#
# ### Sortieren
#
# Ausgaben können auch weiterverarbeitet werden, um beispielsweise Reports zu erstellen.
#
# Hier werden durch das Kennwort ```ASC``` die Ausgaben nach dem davor genannten Attribut ```Lat``` geordnet ausgegeben. ```DESC``` ist das Schlüsselwort für eine umgekehrte Anordnung.
#
# ```
# ps.sqldf("""SELECT * FROM performance_data ORDER BY Lat ASC """)
# ```

# %%
# Beispiel
ps.sqldf("""SELECT * FROM performance_data ORDER BY Lat ASC """)
# Out:
#        OBJECTID                     Anlage Baumnummer  \
# 0          3773  Fernkreuzweg - Spielplatz         19
# 1          4258  Fernkreuzweg - Spielplatz          1
# 2          3774  Fernkreuzweg - Spielplatz         20
# 3          3772  Fernkreuzweg - Spielplatz         18
# 4          4363  Fernkreuzweg - Spielplatz         17
# ...         ...                        ...        ...
# 13412      6082      Josef-Schraffl-Straße          8
# 13413      6377      Josef-Schraffl-Straße          4
# 13414      6083      Josef-Schraffl-Straße          9
# 13415      6378      Josef-Schraffl-Straße          7
# 13416      6367          Wasserwerk Mühlau          4
#
#                      Gattung_Dt                            Gattung_Lat  \
# 0                     Mehlbeere                            Sorbus aria
# 1                     Mehlbeere                            Sorbus aria
# 2      Rotblättriger Spitzahorn          Acer platanoides 'Schwedleri'
# 3                     Bergahorn                    Acer pseudoplatanus
# 4                     Mehlbeere                            Sorbus aria
# ...                         ...                                    ...
# 13412     Nichtfruchtende Esche  Fraxinus excelsior 'Westhof's Glorie'
# 13413             Gemeine Esche                     Fraxinus excelsior
# 13414     Nichtfruchtende Esche  Fraxinus excelsior 'Westhof's Glorie'
# 13415             Gemeine Esche                     Fraxinus excelsior
# 13416     Scharlach Roßkastanie              Aesculus carnea 'Briotii'
#
#       Pflanzdatum           X            Y        Lon        Lat
# 0            None  80954.1600  232324.5800  11.401915  47.224834
# 1            None  80972.1000  232326.9500  11.402153  47.224853
# 2            None  80958.1800  232327.2900  11.401969  47.224858
# 3            None  80944.4400  232328.3200  11.401788  47.224868
# 4            None  80949.9700  232332.8100  11.401861  47.224908
# ...           ...         ...          ...        ...        ...
# 13412  22.10.2015  81941.4109  239525.1977  11.416264  47.289468
# 13413        None  81952.2634  239526.2612  11.416408  47.289476
# 13414  22.10.2015  81964.4205  239527.3937  11.416569  47.289485
# 13415        None  81989.2690  239528.8456  11.416898  47.289494
# 13416  23.11.2017  81890.7781  239527.5292  11.415596  47.289495
#
# [13417 rows x 10 columns]

# %% [markdown]
# ### Aggregation
#
# Über der Schlüsselwort ```SUM``` lassen sich Summen über Attribute bilden.
#
# ```
# ps.sqldf("""SELECT SUM(Height_m) FROM performance_data""")
# ```

# %%
# Beispiel
ps.sqldf("""SELECT SUM(Height_m) FROM performance_data""")
# Out:
#    SUM(Height_m)
# 0         141126

# %% [markdown]
# Es lassen sich auch Summen über mehrere Attribute erzeugen, z.B. um die Baumnummern und die Höhen aufzuaddieren:
#
# ```
# ps.sqldf("""SELECT SUM(Height_m), SUM(Baumnummer) FROM performance_data""")
# ```

# %%
# Beispiel
ps.sqldf("""SELECT SUM(Height_m), SUM(Baumnummer) FROM performance_data""")
# Out:
#    SUM(Height_m)  SUM(Baumnummer)
# 0         141126         989802.0

# %% [markdown]
# Außerdem lassen sich die Summen über ein Subset (Selektion) bilden.
#
# Hier werden z.B. nur die Höhen der Bergahorn summiert:
#
# ```
# ps.sqldf("""SELECT SUM(Height_m) FROM performance_data WHERE Gattung_dt="Bergahorn" """)
# ```

# %%
# Beispiel
ps.sqldf("""SELECT SUM(Height_m) FROM performance_data WHERE Gattung_dt="Bergahorn" """)
# Out:
#    SUM(Height_m)
# 0           5964

# %% [markdown]
# Es gibt auch weitere Befehle zur Aggregation, wie z.B. ```COUNT```
# Hier werden alle Tupel (Zeilen in der Tabelle) gezählt:
#
# ```
# ps.sqldf("""SELECT COUNT(*) FROM performance_data""")
# ```

# %%
# Beispiel Anzahl aller Einträge
ps.sqldf("""SELECT COUNT(*) FROM performance_data""")
# Out:
#    COUNT(*)
# 0     13417

# %% [markdown]
# ##  Aufgaben
#
# Nutzen Sie die oben vorgestellten Befehle, um die folgenden Aufgaben zu lösen:
#
# 1. ✍️ Was sind die größten vier Bäume?

# %%
# Lösung
ps.sqldf(""" SELECT * FROM performance_data ORDER BY Height_m DESC LIMIT 4 """)
# Out:
#    OBJECTID                      Anlage Baumnummer     Gattung_Dt  \
# 0         6  Kaiser-Franz-Joseph-Straße         27    Winterlinde
# 1         7  Kaiser-Franz-Joseph-Straße         28    Winterlinde
# 2        13         Kaiser-Josef-Straße         31  Gemeine Esche
# 3        30             Klappholzstraße         19   Vogelkirsche
#
#           Gattung_Lat Pflanzdatum          X           Y        Lon  \
# 0       Tilia cordata        None  81196.580  238044.950  11.406151
# 1       Tilia cordata        None  81189.780  238038.020  11.406060
# 2  Fraxinus excelsior        None  79929.750  236491.980  11.389134
# 3        Prunus avium        None  82046.974  237292.478  11.417251
#
#          Lat  Height_m
# 0  47.276248        19
# 1  47.276187        19
# 2  47.262437        19
# 3  47.269375        19

# %% [markdown]
# Möchten wir nicht alle, sondern nur ein einzigen kleinsten oder größten Wert, können wir diesen auch über die `Min()` und `Max()` Funktion abfragen:

# %%
ps.sqldf(""" SELECT *, Max(Height_m) FROM performance_data""")
# Out:
#    OBJECTID                      Anlage Baumnummer   Gattung_Dt  \
# 0         6  Kaiser-Franz-Joseph-Straße         27  Winterlinde
#
#      Gattung_Lat Pflanzdatum         X          Y        Lon        Lat  \
# 0  Tilia cordata        None  81196.58  238044.95  11.406151  47.276248
#
#    Height_m  Max(Height_m)
# 0        19             19

# %% [markdown]
# 2. ✍️ Wie viele Bäume stehen in der Klappholzstraße?

# %%
# Lösung
ps.sqldf("""SELECT count(*) FROM performance_data WHERE Anlage="Klappholzstraße" """)
# Out:
#    count(*)
# 0        24

# %% [markdown]
# Neben der Summation gibt es noch weitere Operationen, um das Minimum (```MIN```), Maximum (```MAX```) oder den Durchschnitt (```AVG```) zu finden.
#
# So lässt sich zum Beispiel die durchschnittliche Höhe der Bäume bestimmen:
#
# ```
# ps.sqldf(""" SELECT AVG(Height_m) FROM performance_data """)
# ```

# %% [markdown]
# 3. ✍️ Wie groß sind Winterlinden vergleichen mit Vogelkirschen im Durchschnitt?
#
# Nutzen Sie dazu zwei separate Befehle. Später lernen wir, wie dies auch mit einem Befehl möglich ist.

# %%
# Lösung
ps.sqldf(""" SELECT AVG(Height_m) FROM performance_data WHERE Gattung_Dt = "Winterlinde" """)
# Out:
#    AVG(Height_m)
# 0      10.329768

# %%
# Lösung
ps.sqldf(""" SELECT AVG(Height_m) FROM performance_data WHERE Gattung_Dt = "Vogelkirsche" """)
# Out:
#    AVG(Height_m)
# 0      10.594595

# %% [markdown]
# 4. ✍️ Wie viele gemeine Eschen (Gattung_Dt = "Gemeine Esche") wachsen südlicher als Lat = 47.27 ?

# %%
# Lösung
ps.sqldf(""" SELECT Count(*) FROM performance_data WHERE Gattung_Dt = "Gemeine Esche" and Lat<47.27""")
# Out:
#    Count(*)
# 0       246

# %% [markdown]
# ### Gruppieren
#
# Operationen, wie ```AVG```, `MIN` und `MAX`  lassen sich mit den Schlüsselwort ```GROUP BY``` automatisiert für mehrere Gruppen durchführen. So lässt sich z.B. die Höhe getrennt nach Gattung auswerten.
#
# ```
# ps.sqldf("""SELECT Gattung_Dt, AVG(Height_m) FROM performance_data GROUP BY Gattung_Dt""")
# ```

# %%
# Beispiel
ps.sqldf("""SELECT Gattung_Dt, AVG(Height_m) FROM performance_data GROUP BY Gattung_Dt""")
# Out:
#                         Gattung_Dt  AVG(Height_m)
# 0       Abendländischer Lebensbaum      10.371429
# 1        Allershausener Spitzahorn      15.100000
# 2                        Amberbaum      10.458716
# 3              Amerikanische Linde      18.000000
# 4        Amerikanischer Zürgelbaum      15.333333
# ..                             ...            ...
# 268                    Zuckerahorn      15.000000
# 269                Zöschener Ahorn      12.750000
# 270                     Zürgelbaum      10.294118
# 271                        Ölweide       6.666667
# 272  Österreichische Schwarzkiefer      10.678899
#
# [273 rows x 2 columns]

# %% [markdown]
# Hiermit können wir auch die Frage 3 mit einem einzelnen Befehl lösen:

# %%
ps.sqldf("""SELECT Gattung_Dt, AVG(Height_m)  FROM performance_data WHERE Gattung_Dt="Winterlinde" or Gattung_Dt="Vogelkirsche" GROUP BY Gattung_Dt  """)

# %% [markdown]
# 5. ✍️ Was sind die kleinsten Baumarten?

# %%
# Lösung
ps.sqldf("""SELECT Gattung_Dt, AVG(Height_m) FROM performance_data GROUP BY Gattung_Dt ORDER BY AVG(Height_m)  ASC """)
# Out:
#                    Gattung_Dt  AVG(Height_m)
# 0    Geschlitzter Silberahorn       2.000000
# 1               Amur Korkbaum       2.500000
# 2           Großer Lebensbaum       3.000000
# 3                       Pavie       3.000000
# 4            Goldscheinakazie       4.000000
# ..                        ...            ...
# 268        Säulenzitterpappel      17.333333
# 269  Kugelförmige Blumenesche      17.500000
# 270       Amerikanische Linde      18.000000
# 271             Steinweichsel      18.000000
# 272   Säulenförmiger Rotahorn      18.000000
#
# [273 rows x 2 columns]

# %% [markdown]
# ## Besprechung der Aufgaben
#
# - Sind Sie mit ein Aufgaben bis hierhin fertig geworden und haben Sie keine Fragen, so legen Sie die grüne Karte nach oben
# - Sind Sie mit den Aufgaben fertig, aber hätten gerne, dass die Lösungen nocheinmal gemeinsam besprochen werden, legen Sie die gelbe Karte nach oben
#
# ![](https://www.lokalinfo.ch/fileadmin/news_import/image003_03.jpg)

# %% [markdown]
# ### Speichern der Ergebnisse
#
# Die Ergebnisse lassen sich über eine Zuweisung in einem neuen DataFrame speichern und dann z.B. als CSV Datei für einen Report zu extrahieren.

# %%
# Beispiel
new_table = ps.sqldf("""SELECT Gattung_Dt, AVG(Height_m) FROM performance_data GROUP BY Gattung_Dt ORDER BY AVG(Height_m)  ASC """)
print(new_table)
# Out:
#                    Gattung_Dt  AVG(Height_m)
# 0    Geschlitzter Silberahorn       2.000000
# 1               Amur Korkbaum       2.500000
# 2           Großer Lebensbaum       3.000000
# 3                       Pavie       3.000000
# 4            Goldscheinakazie       4.000000
# ..                        ...            ...
# 268        Säulenzitterpappel      17.333333
# 269  Kugelförmige Blumenesche      17.500000
# 270       Amerikanische Linde      18.000000
# 271             Steinweichsel      18.000000
# 272   Säulenförmiger Rotahorn      18.000000
#
# [273 rows x 2 columns]

# %% [markdown]
# ### Logische Verknüpfungen
#
# Durch die logischen Operatoren ```OR```und ```AND``` lassen sich auch komplexere Abfragen gestalten. Zum Beispiel die Suche nach besonders großen Bäumen in einem Park:
#
# ```ps.sqldf(""" SELECT AVG(VO2_max), height, weight FROM performance_data WHERE height < 170 AND weight > 90 """)```

# %%
# Beispiel
ps.sqldf(""" SELECT * FROM performance_data WHERE Height_m > 17 AND Anlage = "Klappholzstraße" """)
# Out:
#    OBJECTID           Anlage Baumnummer                    Gattung_Dt  \
# 0        30  Klappholzstraße         19                  Vogelkirsche
# 1        35  Klappholzstraße         27                  Vogelkirsche
# 2        37  Klappholzstraße         29        Japanischer Schnurbaum
# 3      1698  Klappholzstraße         12                  Vogelkirsche
# 4      1699  Klappholzstraße         13                   Eschenahorn
# 5      8273  Klappholzstraße         17                  Vogelkirsche
# 6     12898  Klappholzstraße          9  Gefülltblühende Vogelkirsche
#
#             Gattung_Lat Pflanzdatum           X            Y        Lon  \
# 0          Prunus avium        None  82046.9740  237292.4780  11.417251
# 1          Prunus avium        None  82134.8810  237369.2040  11.418426
# 2      Sophora japonica        None  82161.3790  237412.7580  11.418784
# 3          Prunus avium        None  81995.4350  237264.3940  11.416564
# 4          Acer negundo        None  82000.1410  237260.0190  11.416626
# 5          Prunus avium        None  82024.5620  237278.1770  11.416952
# 6  Prunus avium 'Plena'  30.11.2021  81969.9669  237255.9202  11.416226
#
#          Lat  Height_m
# 0  47.269375        19
# 1  47.270055        18
# 2  47.270443        19
# 3  47.269129        19
# 4  47.269089        18
# 5  47.269250        18
# 6  47.269056        19

# %% [markdown]
# # ✍️ Aufgaben
#
# 1. ✍️  In welcher Anlage stehen die meisten Bäume?

# %%
ps.sqldf(""" SELECT Anlage, COUNT(*) FROM performance_data GROUP BY Anlage ORDER BY COUNT(*)""")
# Out:
#                                  Anlage  COUNT(*)
# 0                                Am See         1
# 1    An-der-Lan-Str. 41/43 - Spielplatz         1
# 2                Andreas Hoferstraße 39         1
# 3              Anna-Stainer-Knittel-Weg         1
# 4                       Botanikerstraße         1
# ..                                  ...       ...
# 622                               Pradl       294
# 623                   Kranebitter Allee       297
# 624                Grünbacher-Promenade       367
# 625                      Roßaupromenade       378
# 626                      Kurpark - Igls       545
#
# [627 rows x 2 columns]

# %% [markdown]
# 2. ✍️ Was ist die häufigste Baumart?

# %%
ps.sqldf(""" SELECT Gattung_Dt, COUNT(*) FROM performance_data GROUP BY Gattung_Dt ORDER BY COUNT(*)""")
# Out:
#                 Gattung_Dt  COUNT(*)
# 0             Birkenpappel         1
# 1        Echter Mammutbaum         1
# 2       Frühlingstamariske         1
# 3    Goldgelber Tulpenbaum         1
# 4        Großer Lebensbaum         1
# ..                     ...       ...
# 268            Winterlinde       561
# 269              Bergahorn       563
# 270            Roßkastanie       603
# 271              Sandbirke       617
# 272             Spitzahorn       735
#
# [273 rows x 2 columns]

# %% [markdown]
# 3. ✍️ Welche ist der westlichste Baum?

# %%
ps.sqldf(""" SELECT * FROM performance_data ORDER BY Lon ASC""")
# Out:
#        OBJECTID                              Anlage Baumnummer  \
# 0         12928  Kranebitter Allee - Umkehrschleife          1
# 1          9921  Kranebitter Allee - Umkehrschleife          3
# 2         12929  Kranebitter Allee - Umkehrschleife          2
# 3          7017                      Sauerweinwiese         27
# 4          7019                      Sauerweinwiese         29
# ...         ...                                 ...        ...
# 13412     11481                      Roßaupromenade        327
# 13413      7063                      Roßaupromenade        326
# 13414      3840                      Roßaupromenade        328
# 13415      3841                      Roßaupromenade        329
# 13416      3818                      Roßaupromenade        330
#
#                          Gattung_Dt                    Gattung_Lat  \
# 0          Rotblättriger Spitzahorn  Acer platanoides 'Schwedleri'
# 1                       Hopfenbuche            Ostrya carpinifolia
# 2          Rotblättriger Spitzahorn  Acer platanoides 'Schwedleri'
# 3                Herbstflammenahorn  Acer freemanii 'Auttum Blaze'
# 4                             Föhre               Pinus sylvestris
# ...                             ...                            ...
# 13412                   Trauerweide           Salix alba 'Tristis'
# 13413  Gefülltblühende Vogelkirsche           Prunus avium 'Plena'
# 13414                   Trauerweide           Salix alba 'Tristis'
# 13415                   Trauerweide           Salix alba 'Tristis'
# 13416                   Silberweide                     Salix alba
#
#       Pflanzdatum           X            Y        Lon        Lat  Height_m
# 0      18.11.2021  75060.1784  236687.1221  11.324835  47.264765        19
# 1      04.12.2019  75068.4121  236664.8931  11.324940  47.264564         3
# 2      18.11.2021  75074.7596  236686.2080  11.325028  47.264755         2
# 3      10.11.2016  75103.6790  236734.7740  11.325418  47.265189        19
# 4      10.11.2016  75106.0120  236726.6110  11.325447  47.265115        19
# ...           ...         ...          ...        ...        ...       ...
# 13412  01.05.1983  84625.7100  237038.5100  11.451273  47.266765        12
# 13413  14.04.2016  84642.3455  237031.1981  11.451492  47.266697        14
# 13414  01.05.1983  84667.7800  237033.2000  11.451828  47.266712         8
# 13415  01.05.1983  84671.9100  237037.2000  11.451884  47.266747        15
# 13416  01.05.1983  84676.8100  237035.2700  11.451948  47.266729        18
#
# [13417 rows x 11 columns]

# %% [markdown]
# 4. ✍️ Was ist der älteste und der jüngste Baum im Kataster? Wo steht er und was für eine Gattung ist es?

# %%
ps.sqldf("""  SELECT Anlage, Min(Pflanzdatum) FROM performance_data GROUP BY Anlage""")
# Out:
#                                 Anlage Min(Pflanzdatum)
# 0                            Adamgasse       01.02.1993
# 1                      Adamgasse - Süd       01.02.1992
# 2                  Adolf-Pichler-Platz       08.05.2013
# 3     Adolf-Pichler-Platz - Spielplatz       31.10.2002
# 4    Alois-Schrott-Straße - Spielplatz       26.11.2018
# ..                                 ...              ...
# 622        Zeughausg.1a-Kapuzienerg.4b             None
# 623                      Zeughausgasse       11.05.2021
# 624                       Zollerstraße             None
# 625                   Zollerstraße 2-4             None
# 626                       Ägidibrunnen             None
#
# [627 rows x 2 columns]

# %%
ps.sqldf("""  SELECT Anlage, Gattung_dt, Min(Pflanzdatum) FROM performance_data""")
# Out:
#               Anlage              Gattung_Dt Min(Pflanzdatum)
# 0  Unterbergerstraße  Japanischer Schnurbaum       01.01.1974

# %%
ps.sqldf("""  SELECT Anlage, Gattung_dt, Max(Pflanzdatum) FROM performance_data""")
# Out:
#                                    Anlage  Gattung_Dt Max(Pflanzdatum)
# 0  Villa Blanka - Judenbühel - Spielplatz  Stieleiche       31.12.2020

# %% [markdown]
# ## Besprechung der Aufgaben
#
# - Sind Sie mit ein Aufgaben bis hierhin fertig geworden und haben Sie keine Fragen, so legen Sie die grüne Karte nach oben
# - Sind Sie mit den Aufgaben fertig, aber hätten gerne, dass die Lösungen nocheinmal gemeinsam besprochen werden, legen Sie die gelbe Karte nach oben
#
# ![](https://www.lokalinfo.ch/fileadmin/news_import/image003_03.jpg)

# %% [markdown]
# # 🤓 Pandas
# ## Optionale Aufgabe für diejengien die schneller fertig sind:
#
# Das Paket Pandas bietet eine etwas andere Syntax, um in Python DataFrames auszuwerten. Versuchen sie Anhand der [Dokumentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) die SQL-Befehle mittels Pandas Syntax umzusetzen.
#
# 1. ✍️  In welcher Anlage stehen die meisten Bäume?

# %% [markdown]
# 2. ✍️ Was ist die häufigste Baumart?

# %% [markdown]
# 3. ✍️ Welche ist der westlichste Baum?

# %% [markdown]
# 4. ✍️ Was ist der älteste und der jüngste Baum im Kataster? Wo steht er und was für eine Gattung ist es?

# %% [markdown]
# ## 🤓 Interkative Visualisierung
#
# Das Paket [ploty](https://plotly.com/python/scatter-plots-on-maps/) erlaubt interkative Plots und Karten zu erstellen.

# %%
import plotly.graph_objects as go

import pandas as pd

fig = go.Figure(data=go.Scattergeo(
        lon = performance_data['Lon'],
        lat = performance_data['Lat'],
        text = performance_data['Gattung_Dt'],
        mode = 'markers'
        ))

# %%
fig.update_layout(
        title = 'Baumkataster Innsbruck <br>(Hover for tree type)',
        geo_scope='europe',
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d702e197-c464-4b75-b372-890d1b447918" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d702e197-c464-4b75-b372-890d1b447918")) {                    Plotly.newPlot(                        "d702e197-c464-4b75-b372-890d1b447918",                        [{"lat":[47.27688375,47.27681777,47.27675721,47.27650272,47.2763125,47.27624798,47.2761865,47.2761227,47.27605794,47.27599484,47.27593165,47.26253098,47.26243696,47.26234712,47.26235825,47.26227007,47.271693,47.27188325,47.27195483,47.27201888,47.26714106,47.26712978,47.26712138,47.26711543,47.26709845,47.26709323,47.26706409,47.26920515,47.26931584,47.26937546,47.26945198,47.26951196,47.26964882,47.26983472,47.2700545,47.27039693,47.27044287,47.25243471,47.2523715,47.27205168,47.27203188,47.27201174,47.27199397,47.27191927,47.27190377,47.27197483,47.27195989,47.27247547,47.26443274,47.26444684,47.26444037,47.2644572,47.26447896,47.26450295,47.26452135,47.26453571,47.26455202,47.26457122,47.26459368,47.26462234,47.26971296,47.26991151,47.27021168,47.27043504,47.27051989,47.27248976,47.27257093,47.27261263,47.27193138,47.27184683,47.27183111,47.27189015,47.27179409,47.26130622,47.26645176,47.26649621,47.26659387,47.26655629,47.26659355,47.26664483,47.26668964,47.26672575,47.266785,47.26698579,47.2748136,47.27487769,47.2753032,47.27539854,47.27548904,47.27557024,47.27565379,47.27579467,47.27587978,47.27613634,47.27665374,47.27673753,47.27690536,47.27699419,47.27586966,47.27593386,47.27474786,47.27606091,47.27612405,47.27631449,47.27637878,47.27644222,47.27650407,47.27657029,47.27663428,47.27669699,47.27257909,47.27265677,47.27337696,47.27346613,47.27365255,47.27375181,47.27385447,47.27448673,47.27457154,47.27467368,47.27475985,47.27474751,47.27533691,47.27554616,47.22690412,47.22720529,47.22720188,47.22730801,47.22729276,47.22722942,47.22724902,47.22732104,47.22740862,47.22739471,47.22738379,47.2274052,47.22744993,47.22746529,47.22751802,47.22755133,47.27462793,47.27464156,47.27461613,47.27459861,47.27456317,47.27451063,47.27446791,47.27441592,47.27436656,47.27445091,47.27285313,47.27166071,47.2717243,47.2718089,47.22662522,47.22664744,47.22689822,47.26352799,47.26346076,47.26338051,47.26329312,47.26322833,47.26320267,47.26311526,47.26312389,47.26304977,47.26297778,47.26279758,47.27274219,47.27280755,47.27291581,47.26717945,47.27442272,47.27431084,47.2643867,47.26415536,47.26827004,47.26810914,47.26795713,47.26791409,47.26789441,47.26783274,47.26782339,47.27205133,47.27223926,47.27230827,47.27598396,47.27249931,47.27248445,47.27252755,47.2670413,47.26715256,47.27315508,47.27302189,47.27299277,47.27297066,47.27296529,47.27294433,47.27301435,47.27299955,47.27298636,47.27297953,47.27297285,47.2729178,47.2728781,47.27287324,47.27286805,47.27305371,47.27377067,47.27383603,47.27390537,47.27393475,47.27402318,47.27397933,47.27405036,47.27426824,47.27434215,47.27063753,47.27072815,47.27081726,47.27090196,47.26062525,47.28104948,47.26407981,47.27147925,47.27173871,47.27173521,47.27182452,47.27195615,47.25508287,47.25504858,47.2550156,47.2549,47.25460283,47.2546246,47.2546689,47.25466977,47.25470436,47.25688877,47.25695175,47.25698218,47.25704278,47.25748204,47.25773174,47.25775562,47.25784296,47.25803017,47.25807295,47.26016095,47.27522381,47.26640062,47.26630627,47.26611312,47.2545678,47.26504231,47.25071682,47.25064875,47.25061841,47.26088594,47.28314397,47.28323882,47.28344709,47.28357377,47.28369731,47.2839422,47.28406978,47.28417951,47.2833619,47.25520266,47.25518245,47.26774338,47.26780437,47.26700682,47.26700024,47.266974,47.26694093,47.27447717,47.27452418,47.27455026,47.27468046,47.27270044,47.2736465,47.27372326,47.27386846,47.27387978,47.26709314,47.26022947,47.26024818,47.26026058,47.260709 ...
